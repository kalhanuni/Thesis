# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
DATA_DIR = '/content/gdrive/MyDrive/Thesis/dance/dance/data/'

# %%
# !pip uninstall rpy2 -y
# !pip install rpy2==3.5.1
# Out:
# Found existing installation: rpy2 3.5.5
# Uninstalling rpy2-3.5.5:
#   Successfully uninstalled rpy2-3.5.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 KB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rpy2: filename=rpy2-3.5.1-cp38-cp38-linux_x86_64.whl size=310198 sha256=d331fd3622443c66a17b2389c22c2613ce7fdba32678d0b44b7b2b91c9e17d00
#   Stored in directory: /root/.cache/pip/wheels/6b/40/7d/f63e87fd83e8b99ee837c8e3489081c4b3489134bc520235ed
# Successfully built rpy2
# ...

# %%
# %reload_ext rpy2.ipython

# %%
# %%R
# dat <- readRDS('/content/gdrive/MyDrive/Thesis/dance/dance/data/mouse_data_denoised/rna_denoised.rds')
# names(dat)
# Out:
# [1] "estimate"             "se"                   "info"
# [4] "est.before.shrinkage" "predictable"

# %%
# %%R
# install.packages("BiocManager")
# BiocManager::install("rhdf5")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/BiocManager_1.30.19.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 264151 bytes (257 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# %%R
# library(rhdf5)
# h5createFile("/content/gdrive/MyDrive/Thesis/dance/dance/data/mouse_data_denoised_transp.h5")
# h5write(dat$estimate, "/content/gdrive/MyDrive/Thesis/dance/dance/data/mouse_data_denoised_transp.h5","dat")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: You created a large dataset with compression and chunking.
# The chunk size is equal to the dataset dimensions.
# If you want to read subsets of the dataset, you should testsmaller chunk sizes to improve read times.
